# %% [markdown]
# Data Transformer

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
x=pd.DataFrame({"A":[1,2,2,3], "B":[11,8,1,3]})
x
# Out:
#    A   B
# 0  1  11
# 1  2   8
# 2  2   1
# 3  3   3

# %%
x.describe()
# Out:
#               A          B
# count  4.000000   4.000000
# mean   2.000000   5.750000
# std    0.816497   4.573474
# min    1.000000   1.000000
# 25%    1.750000   2.500000
# 50%    2.000000   5.500000
# 75%    2.250000   8.750000
# max    3.000000  11.000000

# %%
ss=StandardScaler()
ss.fit(x)
# Out:
# StandardScaler()

# %%
ss.mean_
# Out:
# array([2.  , 5.75])

# %%
ss.var_
# Out:
# array([ 0.5   , 15.6875])

# %%
x_scaled=ss.transform(x)
x_scaled
# Out:
# array([[-1.41421356,  1.32550825],
#        [ 0.        ,  0.56807496],
#        [ 0.        , -1.19926937],
#        [ 1.41421356, -0.69431384]])

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#               0         1
# count  4.000000  4.000000
# mean   0.000000  0.000000
# std    1.154701  1.154701
# min   -1.414214 -1.199269
# 25%   -0.353553 -0.820553
# 50%    0.000000 -0.063119
# 75%    0.353553  0.757433
# max    1.414214  1.325508

# %% [markdown]
# Encoding the Categorical Data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Dangerous"]=le.fit_transform(df["Dangerous"])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Dangerous'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3840e086184c> in <cell line: 3>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le=LabelEncoder()
# ----> 3 df["Dangerous"]=le.fit_transform(df["Dangerous"])
#       4 df
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming 'y' contains your target variable (Dangerous)
le = LabelEncoder()
y_encoded = le.fit_transform(y) # Encode the target variable 'y'

# Create a new column in your DataFrame to store the encoded target
df["Dangerous"] = y_encoded # Add encoded target to df

# Now you can access the 'Dangerous' column:
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-dcb157035db2> in <cell line: 6>()
#       4 # Assuming 'y' contains your target variable (Dangerous)
#       5 le = LabelEncoder()
# ----> 6 y_encoded = le.fit_transform(y) # Encode the target variable 'y'
#       7
#       8 # Create a new column in your DataFrame to store the encoded target
#
# NameError: name 'y' is not defined

# %%
# Install scikit-learn if you haven't already
# !pip install scikit-learn

# Now import LabelEncoder
from sklearn.processing import LabelEncoder
le=LabelEncoder()
df["Dangerous"]=le.fit_transform(df["Dangerous"])
df
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-63da37d7b5e5> in <cell line: 5>()
#       3
#       4 # Now import LabelEncoder
# ----> 5 from sklearn.processing import LabelEncoder
#       6 le=LabelEncoder()
#       7 df["Dangerous"]=le.fit_transform(df["Dangerous"])
#
# ModuleNotFoundError: No module named 'sklearn.processing'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(dtype=np.int)
df[["weight"]]=oe.fit_transform(df[["weight"]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-287dd69685e5> in <cell line: 3>()
#       1 import numpy as np
#       2 from sklearn.preprocessing import OrdinalEncoder
# ----> 3 oe=OrdinalEncoder(dtype=np.int)
#       4 df[["weight"]]=oe.fit_transform(df[["weight"]])
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     322
#     323         if attr in __former_attrs__:
# --> 324             raise AttributeError(__former_attrs__[attr])
#     325
#     326         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(dtype = np.int, sparse=False,drop="first")
color_encoded=ohe.fit_transform(df[["color"]])
color_encoded
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-4e0077907eba> in <cell line: 4>()
#       2 import numpy as np
#       3 from sklearn.preprocessing import OneHotEncoder
# ----> 4 ohe = OneHotEncoder(dtype = np.int, sparse=False,drop="first")
#       5 color_encoded=ohe.fit_transform(df[["color"]])
#       6 color_encoded
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     322
#     323         if attr in __former_attrs__:
# --> 324             raise AttributeError(__former_attrs__[attr])
#     325
#     326         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np # Import numpy

# Use int or a specific NumPy integer type like np.int64
ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
# Alternatively, use: ohe = OneHotEncoder(dtype=np.int64, sparse=False, drop="first")
color_encoded = ohe.fit_transform(df[["color"]])
color_encoded
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-783a7cae3712> in <cell line: 5>()
#       3
#       4 # Use int or a specific NumPy integer type like np.int64
# ----> 5 ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
#       6 # Alternatively, use: ohe = OneHotEncoder(dtype=np.int64, sparse=False, drop="first")
#       7 color_encoded = ohe.fit_transform(df[["color"]])
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
from sklearn.preprocessing import OrdinalEncoder
import numpy as np # Import numpy

# Use int or a specific NumPy integer type like np.int64
oe = OrdinalEncoder(dtype=int)
# Alternatively, use: oe = OrdinalEncoder(dtype=np.int64)
df[["weight"]] = oe.fit_transform(df[["weight"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-65089b2c7601> in <cell line: 7>()
#       5 oe = OrdinalEncoder(dtype=int)
#       6 # Alternatively, use: oe = OrdinalEncoder(dtype=np.int64)
# ----> 7 df[["weight"]] = oe.fit_transform(df[["weight"]])
#
# NameError: name 'df' is not defined

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder
# ohe.get_feature_names()

# %%
df2=pd.DataFrame(color_encoded,columns=ohe.get_feature_names_out())
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f4170e80c44b> in <cell line: 1>()
# ----> 1 df2=pd.DataFrame(color_encoded,columns=ohe.get_feature_names_out())
#       2 df2
#
# NameError: name 'color_encoded' is not defined

# %%
df=pd.concat((df,df2)),axis=1)
df
# Out:
#   File "<ipython-input-31-375c8d592a96>", line 1
#     df=pd.concat((df,df2)),axis=1)
#                                  ^
# SyntaxError: unmatched ')'

# %%
df.drop(columns=["color"],inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-96e2a71f8675> in <cell line: 1>()
# ----> 1 df.drop(columns=["color"],inplace=True)
#       2 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
df[["Years"]]=mms.fit_transform(df[["Years"]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-3d90791fc633> in <cell line: 3>()
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 mms = MinMaxScaler()
# ----> 3 df[["Years"]]=mms.fit_transform(df[["Years"]])
#
# TypeError: 'type' object is not subscriptable

# %%
data=pd.DataFrame([[1],[4],[np.NaN],[8],[11]],columns=['A'])

# %%
data
# Out:
#       A
# 0   1.0
# 1   4.0
# 2   NaN
# 3   8.0
# 4  11.0

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ("imp",SimpleImputer(strategy="mean")),
    ("scaler",MinMaxScaler())
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-36d239da3be2> in <cell line: 1>()
#       1 pipe = Pipeline([
# ----> 2     ("imp",SimpleImputer(strategy="mean")),
#       3     ("scaler",MinMaxScaler())
#       4 ])
#
# NameError: name 'SimpleImputer' is not defined

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer # Import SimpleImputer from sklearn.impute
from sklearn.preprocessing import MinMaxScaler

pipe = Pipeline([
    ("imp",SimpleImputer(strategy="mean")),
    ("scaler",MinMaxScaler())
])

# %%
pipe["imp"]
SimpleImputer()
# Out:
# SimpleImputer()

# %%
pipe["scaler"]
# Out:
# MinMaxScaler()

# %%
pipe.fit_transform(data)
# Out:
# array([[0. ],
#        [0.3],
#        [0.5],
#        [0.7],
#        [1. ]])

# %% [markdown]
# Column Transformer

# %%
data=pd.DataFrame([[1],[4],[np.NaN],[8],[11]],columns=['A'])
data
# Out:
#       A
# 0   1.0
# 1   4.0
# 2   NaN
# 3   8.0
# 4  11.0

# %%
from sklearn.compose import ColumnTransformer
column_transformer = ColumnTransformer([
         ("imp",SimpleImputer(strategy="mean") ,["A"]),
         ("scaler",MinMaxScaler(),["A"])
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14d40fe1332f> in <cell line: 2>()
#       1 from sklearn.compose import ColumnTransformer
#       2 column_transformer = ColumnTransformer([
# ----> 3          ("imp",SimpleImputer(strategy="mean") ,["A"]),
#       4          ("scaler",MinMaxScaler(),["A"])
#       5 ])
#
# NameError: name 'SimpleImputer' is not defined

# %%
column_transformer.fit_transform(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-71c744005325> in <cell line: 1>()
# ----> 1 column_transformer.fit_transform(data)
#
# NameError: name 'column_transformer' is not defined

# %% [markdown]
# Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Dangerous"]=le.fit_transform(df["Dangerous"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bc78b921998> in <cell line: 3>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le=LabelEncoder()
# ----> 3 df["Dangerous"]=le.fit_transform(df["Dangerous"])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Data
data = {
    'Color': ['Green', 'Red', 'Blue', 'Green', 'Green'],
    'Years': [2.30, 4.10, 1.40, 3.25, 5.20],
    'Strength': [210.00, 100.00, 283.75, 313.00, 512.00],
    'Height': [170.00, 269.25, 412.00, 123.00, 372.00],
    'Weight': ['20 to 30 kg', '10 to 20 kg', '0 to 10 kg', '10 to 20 kg', '0 to 10 kg'],
    'Dangerous': ['Yes', 'No', 'No', 'Yes', 'Yes']
}

# Creating DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#    Color  Years  Strength  Height       Weight Dangerous
# 0  Green   2.30    210.00  170.00  20 to 30 kg       Yes
# 1    Red   4.10    100.00  269.25  10 to 20 kg        No
# 2   Blue   1.40    283.75  412.00   0 to 10 kg        No
# 3  Green   3.25    313.00  123.00  10 to 20 kg       Yes
# 4  Green   5.20    512.00  372.00   0 to 10 kg       Yes

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Dangerous"]=le.fit_transform(df["Dangerous"])

# %%
df["Dangerous"]
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Dangerous, dtype: int64

# %%
df
# Out:
#    Color  Years  Strength  Height       Weight  Dangerous
# 0  Green   2.30    210.00  170.00  20 to 30 kg          1
# 1    Red   4.10    100.00  269.25  10 to 20 kg          0
# 2   Blue   1.40    283.75  412.00   0 to 10 kg          0
# 3  Green   3.25    313.00  123.00  10 to 20 kg          1
# 4  Green   5.20    512.00  372.00   0 to 10 kg          1

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-7c4c7eb10b2e> in <cell line: 2>()
#       1 from sklearn.preprocessing import OrdinalEncoder
# ----> 2 oe=OrdinalEncoder(dtype=np.int)
#       3 df[["Weight"]]=oe.fit_transform(df[["Weight"]])
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     322
#     323         if attr in __former_attrs__:
# --> 324             raise AttributeError(__former_attrs__[attr])
#     325
#     326         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(dtype=np.int)
df[["Weight"]]=oe.fit_transform(df[["Weight"]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-7c4c7eb10b2e> in <cell line: 2>()
#       1 from sklearn.preprocessing import OrdinalEncoder
# ----> 2 oe=OrdinalEncoder(dtype=np.int)
#       3 df[["Weight"]]=oe.fit_transform(df[["Weight"]])
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     322
#     323         if attr in __former_attrs__:
# --> 324             raise AttributeError(__former_attrs__[attr])
#     325
#     326         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
import numpy as np  # Make sure numpy is imported

# Use int or a specific numpy integer type like np.int64 or np.int32
oe = OrdinalEncoder(dtype=int)  # or dtype=np.int64, dtype=np.int32
df[["Weight"]] = oe.fit_transform(df[["Weight"]])

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Use int

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np
ohe = OneHotEncoder(dtype = np.int, sparse=False,drop="first")
color_encoded=ohe.fit_transform(df[["Color"]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f4e4b8287ad0> in <cell line: 3>()
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 import numpy as np
# ----> 3 ohe = OneHotEncoder(dtype = np.int, sparse=False,drop="first")
#       4 color_encoded=ohe.fit_transform(df[["Color"]])
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     322
#     323         if attr in __former_attrs__:
# --> 324             raise AttributeError(__former_attrs__[attr])
#     325
#     326         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Use int instead of np.int for dtype
ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
color_encoded = ohe.fit_transform(df[["Color"]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-69ca83b52319> in <cell line: 5>()
#       3
#       4 # Use int instead of np.int for dtype
# ----> 5 ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
#       6 color_encoded = ohe.fit_transform(df[["Color"]])
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
ohe.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-557db67b48f3> in <cell line: 2>()
#       1 from sklearn.preprocessing import OneHotEncoder
# ----> 2 ohe.get_feature_names()
#
# NameError: name 'ohe' is not defined

# %%
ohe.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-5ee56aa86c86> in <cell line: 1>()
# ----> 1 ohe.get_feature_names_out()
#
# NameError: name 'ohe' is not defined

# %%
df2=pd.DataFrame(color_encoded,columns=ohe.get_feature_names_out())
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-f4170e80c44b> in <cell line: 1>()
# ----> 1 df2=pd.DataFrame(color_encoded,columns=ohe.get_feature_names_out())
#       2 df2
#
# NameError: name 'color_encoded' is not defined

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Assuming 'df' is your DataFrame with the 'Color' column
# Replace this with your actual DataFrame creation if needed
# Example DataFrame:
df = pd.DataFrame({'Color': ['Red', 'Green', 'Blue', 'Red']})


# Create and fit the OneHotEncoder
ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
color_encoded = ohe.fit_transform(df[["Color"]]) # Define color_encoded here

# Now create the DataFrame using color_encoded
df2 = pd.DataFrame(color_encoded, columns=ohe.get_feature_names_out(['Color'])) # Access color_encoded within the same cell
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-73b85aeda1cf> in <cell line: 13>()
#      11
#      12 # Create and fit the OneHotEncoder
# ---> 13 ohe = OneHotEncoder(dtype=int, sparse=False, drop="first")
#      14 color_encoded = ohe.fit_transform(df[["Color"]]) # Define color_encoded here
#      15
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Assuming 'df' is your DataFrame with the 'Color' column
# Replace this with your actual DataFrame creation if needed
# Example DataFrame:
df = pd.DataFrame({'Color': ['Red', 'Green', 'Blue', 'Red']})


# Create and fit the OneHotEncoder
# Replace 'sparse=False' with 'sparse_output=False'
ohe = OneHotEncoder(dtype=int, sparse_output=False, drop="first")
color_encoded = ohe.fit_transform(df[["Color"]]) # Define color_encoded here

# Now create the DataFrame using color_encoded
df2 = pd.DataFrame(color_encoded, columns=ohe.get_feature_names_out(['Color'])) # Access color_encoded within the same cell
df2
# Out:
#    Color_Green  Color_Red
# 0            0          1
# 1            1          0
# 2            0          0
# 3            0          1

# %%
df=pd.concat((df,df2),axis=1)
df
# Out:
#    Color  Color_Green  Color_Red
# 0    Red            0          1
# 1  Green            1          0
# 2   Blue            0          0
# 3    Red            0          1

# %%
df.drop(columns=["Color"],inplace=True)
df
# Out:
#    Color_Green  Color_Red
# 0            0          1
# 1            1          0
# 2            0          0
# 3            0          1

# %%
# Grade calculator function
def calculate_grade(marks):
    if marks >= 90:
        return "A", "Excellent performance!"
    elif marks >= 80:
        return "B", "Very good, keep it up!"
    elif marks >= 70:
        return "C", "Good effort, but room for improvement."
    elif marks >= 60:
        return "D", "Needs more practice."
    else:
        return "F", "Poor performance. Work harder!"

# List to store student results
student_results = []

# Input loop
while True:
    name = input("Enter student name (or type 'exit' to finish): ")
    if name.lower() == 'exit':
        break

    try:
        marks = float(input(f"Enter marks for {name}: "))
        grade, comment = calculate_grade(marks)
        student_results.append({
            "Name": name,
            "Marks": marks,
            "Grade": grade,
            "Comment": comment
        })
        print(f"Grade: {grade} | Comment: {comment}\n")
    except ValueError:
        print("Invalid input. Please enter numeric marks.\n")

# Final output
print("\n📋 Final Student Results:")
for student in student_results:
    print(f"{student['Name']}: Marks = {student['Marks']}, Grade = {student['Grade']}, Comment = {student['Comment']}")
# Out:
# Enter student name (or type 'exit' to finish): prachi
# Enter marks for prachi: 100
# Grade: A | Comment: Excellent performance!
#
# Enter student name (or type 'exit' to finish): exit
#
# 📋 Final Student Results:
# prachi: Marks = 100.0, Grade = A, Comment = Excellent performance!

# %%
class ContactManager:
    def __init__(self):
        self.contacts = []

    def add_contact(self, name, phone):
        self.contacts.append({"Name": name, "Phone": phone})
        print(f"✅ Contact '{name}' added successfully.\n")

    def search_contact(self, name):
        found = [c for c in self.contacts if c["Name"].lower() == name.lower()]
        if found:
            print("🔍 Contact Found:")
            for contact in found:
                print(f"Name: {contact['Name']}, Phone: {contact['Phone']}")
        else:
            print("❌ Contact not found.\n")

    def display_contacts(self):
        if not self.contacts:
            print("📭 No contacts to display.\n")
        else:
            print("\n📋 All Contacts:")
            for i, contact in enumerate(self.contacts, 1):
                print(f"{i}. Name: {contact['Name']}, Phone: {contact['Phone']}")
            print()


# Example usage
if __name__ == "__main__":
    manager = ContactManager()

    while True:
        print("1. Add Contact\n2. Search Contact\n3. Display All Contacts\n4. Exit")
        choice = input("Choose an option (1-4): ")

        if choice == '1':
            name = input("Enter name: ")
            phone = input("Enter phone number: ")
            manager.add_contact(name, phone)

        elif choice == '2':
            name = input("Enter name to search: ")
            manager.search_contact(name)

        elif choice == '3':
            manager.display_contacts()

        elif choice == '4':
            print("👋 Exiting Contact Manager. Goodbye!")
            break

        else:
            print("⚠️ Invalid choice. Please try again.\n")
# Out:
# 1. Add Contact
# 2. Search Contact
# 3. Display All Contacts
# 4. Exit
# Choose an option (1-4): 1
# Enter name: tripti
# Enter phone number: 098978667
# ✅ Contact 'tripti' added successfully.
#
# 1. Add Contact
# 2. Search Contact
# 3. Display All Contacts
# 4. Exit
# Choose an option (1-4): 2
# Enter name to search: tripti
# 🔍 Contact Found:
# Name: tripti, Phone: 098978667
# 1. Add Contact
# 2. Search Contact
# 3. Display All Contacts
# 4. Exit
# Choose an option (1-4): 3
#
# 📋 All Contacts:
# 1. Name: tripti, Phone: 098978667
#
# 1. Add Contact
# 2. Search Contact
# 3. Display All Contacts
# 4. Exit
# Choose an option (1-4): 4
# 👋 Exiting Contact Manager. Goodbye!
